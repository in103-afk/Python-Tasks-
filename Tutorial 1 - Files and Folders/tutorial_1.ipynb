# %% [markdown]
# # Tutorial 1: Working with Files in Python
#
# This tutorial can be found in this link [Working with Files in Python](https://realpython.com/working-with-files-in-python/).
#
# **Note:** Use Markdown headings to create sections in the notebook. Run each snippet of code in one cell.

# %% [markdown]
# ## 1. `with ... open as` pattern

# %%
with open('Coasters.txt', 'r') as f:
    data = f.read()

with open('data.txt', 'w') as f:
    data = 'some data to be written to the file'
    f.write(data)

# %% [markdown]
# ## Getting a directories listing

# %% [markdown]
# ## Directory Listing in Legacy Python Versions

# %%
import os 
print (os.getcwd())
entries=os.listdir('/Users/ilishaanerker/Desktop/CS 315/Week 1/Tutorial 1 - Files and Folders')
for entry in entries:
     print(entry)
# Out:
# /Users/ilishaanerker/Desktop/CS 315/Week 1/Tutorial 1 - Files and Folders
# .Rhistory
# packages.tar
# Coasters.txt
# tutorial_1.ipynb
# .RData
# example_directory
# .Rapp.history
# packages.tar.gz
# data.txt

# %% [markdown]
# ## Creating a Single Directory

# %%
import os

os.mkdir('example_directory/')
from pathlib import Path

p = Path('example_directory/')
p.mkdir()

from pathlib import Path

p = Path('example_directory')
try:
    p.mkdir()
except FileExistsError as exc:
    print(exc)

from pathlib import Path

p = Path('example_directory')
p.mkdir(exist_ok=True)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[85], line 3
#       1 import os
#       2
# ----> 3 os.mkdir('example_directory/')
#       4 from pathlib import Path
#       5
#       6 p = Path('example_directory/')
#
# FileExistsError: [Errno 17] File exists: 'example_directory/'

# %% [markdown]
# ## Creating Multiple Directories

# %%
import os


os.makedirs('2018/10/05')
import os

os.makedirs('2018/10/05', mode=0o770)

import pathlib

p = pathlib.Path('2018/10/05')
p.mkdir(parents=True)

$ mkdir some_directory
$ cd some_directory/
$ mkdir sub_dir
$ touch sub_dir/file1.py sub_dir/file2.py
$ touch data_{01..03}.txt data_{01..03}_backup.txt admin.py tests.py
# Out:
#   Cell In[19], line 14
#     $ mkdir some_directory
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Using String Methods

# %% [markdown]
# >>> import os
#
# >>> # Get .txt files
# >>> for f_name in os.listdir('some_directory'):
# ...     if f_name.endswith('.txt'):
# ...         print(f_name)

# %% [markdown]
# ## Simple Filename Pattern Matching Using fnmatch

# %%
import os
>>> import fnmatch

>>> for file_name in os.listdir('example_directory/'):
...     if fnmatch.fnmatch(file_name, '*.txt'):
...         print(file_name)

# %% [markdown]
# More Advanced Pattern Matching

# %%
for filename in os.listdir('.'):
   if fnmatch.fnmatch(filename, 'data_*_backup.txt'):
     print(filename)

# %% [markdown]
# ## Filename Pattern Matching Using glob

# %%
>>> import glob
>>> glob.glob('*.py')
['admin.py', 'tests.py']
# Out:
# ['admin.py', 'tests.py']

# %%
import glob
>>> for name in glob.glob('*[0-9]*.txt'):
...     print(name)
import glob
>>> for file in glob.iglob('**/*.py', recursive=True):
...     print(file)
from pathlib import Path
>>> p = Path('.')
>>> for name in p.glob('*.p*'):
...     print(name)

# %% [markdown]
# ## Traversing Directories and Processing Files

# %%
for dirpath, dirnames, files in os.walk('.'):
    print(f'Found directory: {dirpath}')
    for file_name in files:
        print(file_name)
# Out:
# Found directory: .
# .Rhistory
# Coasters.txt
# tutorial_1.ipynb
# .RData
# .Rapp.history
# data.txt
# Found directory: ./example_directory

# %%
for dirpath, dirnames, files in os.walk('.', topdown=False):
    print(f'Found directory: {dirpath}')
    for file_name in files:
        print(file_name)
# Out:
# Found directory: ./example_directory
# Found directory: .
# .Rhistory
# Coasters.txt
# tutorial_1.ipynb
# .RData
# .Rapp.history
# data.txt

# %% [markdown]
# ## Making Temporary Files and Directories

# %%
from tempfile import TemporaryFile

# Create a temporary file and write some data to it
fp = TemporaryFile('w+t')
fp.write('Hello universe!')

# Go back to the beginning and read data from file
fp.seek(0)
data = fp.read()

# Close the file, after which it will be removed
fp.close()


with TemporaryFile('w+t') as fp:
    fp.write('Hello universe!')
    fp.seek(0)
    fp.read()

import tempfile
>>> with tempfile.TemporaryDirectory() as tmpdir:
...     print('Created temporary directory ', tmpdir)
...     os.path.exists(tmpdir)
...
# Out:
# Created temporary directory  /var/folders/v0/_fjqg3_145b4021fknmzp2v40000gn/T/tmp2bwh46ew

# %% [markdown]
# ## Deleting Files and Directories

# %%
import os

data_file = '/Users/ilishaanerker/Desktop/CS 315/Week 1/Tutorial 1 - Files and Folders'
os.remove(data_file)


data_file = '/Users/ilishaanerker/Desktop/CS 315/Week 1/Tutorial 1 - Files and Folders'
os.unlink(data_file)


data_file = 'home/data.txt'

# If the file exists, delete it
if os.path.isfile(data_file):
    os.remove(data_file)
else:
    print(f'Error: {data_file} not a valid filename')

import os

data_file = 'home/data.txt'

# Use exception handling
try:
    os.remove(data_file)
except OSError as e:
    print(f'Error: {data_file} : {e.strerror}')

from pathlib import Path

data_file = Path('home/data.txt')

try:
    data_file.unlink()
except IsADirectoryError as e:
    print(f'Error: {data_file} : {e.strerror}')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[41], line 4
#       1 import os
#       2
#       3 data_file = '/Users/ilishaanerker/Desktop/CS 315/Week 1/Tutorial 1 - Files and Folders'
# ----> 4 os.remove(data_file)
#       5
#       6
#       7 data_file = '/Users/ilishaanerker/Desktop/CS 315/Week 1/Tutorial 1 - Files and Folders'
#
# PermissionError: [Errno 1] Operation not permitted: '/Users/ilishaanerker/Desktop/CS 315/Week 1/Tutorial 1 - Files and Folders'

# %% [markdown]
# ## Deleting Directories

# %%
trash_dir = '/Users/ilishaanerker/Desktop/CS 315/Week 1/Tutorial 1 - Files and Folders'

try:
    os.rmdir(trash_dir)
except OSError as e:
    print(f'Error: {trash_dir} : {e.strerror}')

from pathlib import Path

trash_dir = Path('my_documents/bad_dir')

try:
    trash_dir.rmdir()
except OSError as e:
    print(f'Error: {trash_dir} : {e.strerror}')
# Out:
# Error: /Users/ilishaanerker/Desktop/CS 315/Week 1/Tutorial 1 - Files and Folders : Directory not empty
# Error: my_documents/bad_dir : No such file or directory

# %% [markdown]
# ## Deleting Entire Directory Trees

# %%
import shutil

trash_dir = 'my_documents/bad_dir'

try:
    shutil.rmtree(trash_dir)
except OSError as e:
    print(f'Error: {trash_dir} : {e.strerror}')
# Out:
# Error: my_documents/bad_dir : No such file or directory

# %%
for dirpath, dirnames, files in os.walk('.', topdown=False):
    try:
        os.rmdir(dirpath)
    except OSError as ex:
        pass

# %% [markdown]
# ## An Easier Way of Creating Archives

# %%
import shutil

# shutil.make_archive(base_name, format, root_dir)
shutil.make_archive('/Users/ilishaanerker/Desktop/CS 315/Week 1/Tutorial 1 - Files and Folders', 'tar', '/Users/ilishaanerker/Desktop/CS 315/Week 1/Tutorial 1 - Files and Folders')
# Out:
# '/Users/ilishaanerker/Desktop/CS 315/Week 1/Tutorial 1 - Files and Folders.tar'

# %% [markdown]
# ## Reading Multiple Files

# %%
#import fileinput
#for line in fileinput.input():

# %%
# File: fileinput-example.py
#import fileinput
#import sys

#files = fileinput.input()
#for line in files:
    #if fileinput.isfirstline():
        #print(f'\n--- Reading {fileinput.filename()} ---')
    #print(' -> ' + line, end='')
#print()
